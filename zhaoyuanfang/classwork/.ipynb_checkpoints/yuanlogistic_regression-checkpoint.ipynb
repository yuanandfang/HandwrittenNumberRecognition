# %% [markdown]
# # Logistic Regression exercise

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline
plt.rcParams['figure.figsize'] = (15., 12.) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# %load_ext autoreload
# %autoreload 2

# %%
# Read the data for you
data = pd.read_csv('./DSVC/datasets/MNIST.csv',header=0).values # change the path by yourself
imgs = data[0::,1::]
labels = data[::,0]

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = range(10)
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(labels == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(imgs[idx].reshape(28,28).astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %% [markdown]
# # Binary classification
# We use the Logistic Regression to classification handwritten digits wheather it's zero or not. If the handwritten digits is '0' , then the label is 0, otherwise, the label is 1.

# %%
# transform the labels to binary
for i in range(len(labels)):
    if labels[i] != 0:
        labels[i] = 1
        
# 2/3 training set
# 1/3 test set
split_index = len(labels) * 2 //3
X_train = imgs[:split_index]
y_train = labels[:split_index]
X_test = imgs[split_index:]
y_test = labels[split_index:]

X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])#将theta参数标签放入，多出一列
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])

print (X_train.shape)
print (X_test.shape)
# Out:
# (28000, 785)
# (14000, 785)

# %%
#from features import *
#num_color_bins = 10 # Number of bins in the color histogram
#feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
#X_train_feats =X_train  # choose and extract features
#X_test_feats =X_test # choose and extract features
#变换后各维特征有0均值，单位方差。也叫z-score规范（零均值规范化）。计算方式是将特征值减去均值，除以标准差。
X_train_feats = (X_train - np.mean(X_train)) / np.std(X_train) # choose and extract features
X_test_feats = (X_test - np.mean(X_test)) / np.std(X_test) # choose and extract features 
print(X_train_feats.shape)
# Out:
# (28000, 785)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = range(2)
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(labels == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(imgs[idx].reshape(28,28).astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
from DSVC.classifiers import LogisticRegression

# Start training. 
# You should open DSVC/classifiers/logistic_regression.py and implement the function.
# Then run this cell.

classifier = LogisticRegression()
loss_history = classifier.train(
    X_train_feats, 
    y_train,
    learning_rate = 1e-3,
    num_iters = 500,
    batch_size = 64,
)
# Out:
# iteration 0 / 10: loss 0.698626
# iteration 100 / 10: loss 0.196366
# iteration 200 / 10: loss 0.172109
# iteration 300 / 10: loss 0.146444
# iteration 400 / 10: loss 0.160663

# %%
plt.plot(loss_history)

# %%
y_test_pred = classifier.predict(X_test_feats)
print( "The accuracy socre is ", np.mean(y_test == y_test_pred))#预测值作为测试结果
# Out:
# The accuracy socre is  0.9763571428571428

# %% [markdown]
# you should get the accuracy higher than 96%.
#
# ----
#
# ### F1-Measure
# Notice that, if our model always output '1', totally ignoring the input X, we can get a accuracy 90%.So, in this assignment, accuracy is not efficient enough.
#
# We will use F1-Measure to evaluate our model.
#
# You may need this:
# [F1-Measure](https://baike.baidu.com/item/f-measure/913107?fr=aladdin)

# %%
# Calculate the precision(准确率), recall(召回率) and F1
# important： We should consider label '0' as 'positive' here. 
# That means 'True positive' ==> '(y_test == 0) and (y_test_pred == 0)'
# the precision 对于给定的测试数据集，分类器正确分类的样本数与总样本数之比
#recall:计算的是所有检索到的item占所有"应该检索到的item"的比例。
#F1：Precision和Recall加权调和平均 2PR/P+R，是IR（信息检索）领域的常用的一个评价标准，常用于评价分类模型的好坏。
#当F1较高时则能说明试验方法比较有效。
#######Your code here########
TP = 0
FP = 0
FN = 0
TN = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0 and y_test_pred[i] == 0:
        TP += 1 # 预测结果符合
    
    if y_test[i] == 1 and y_test_pred[i] == 0:
        FP += 1 #预测结果不符合
        
    if y_test[i] == 0 and y_test_pred[i] == 1:
        FN += 1 #预测结果 
        
    if y_test[i] == 1 and y_test_pred[i] == 1:
        TN += 1
        
precision = TP / (TP + FP)
recall = TP / (TP + FN)
F1=precision*recall*2/(precision+recall)
print("准确率为：%.11f"%precision) 
print("---------------------------")
print("召回率为：%.11f"%recall) 
print("---------------------------")
print ("F 1   为:%.11f"%F1)
print("---------------------------")
# Out:
# 准确率为：0.96312178388
# ---------------------------
# 召回率为：0.79588944011
# ---------------------------
# F 1   为:0.87155607295
# ---------------------------

# %% [markdown]
# you should get the F1 higher than 85%.

# %% [markdown]
# # Multiclass classification
#
# Now, we use the Logistic Regression to classification handwritten digits. There are 10 class, from '0' to '9'.
#
#
# Hint: The method "one vs all" may helpful. [Here is the introduction to "one vs all"](https://msdn.microsoft.com/library/en-us/Dn905887.aspx).

# %%
# Read the data for you
data = pd.read_csv('./DSVC/datasets/MNIST.csv',header=0).values # change the path by yourself
imgs = data[0::,1::]
labels = data[::,0]
        
# 2/3 training set
# 1/3 test set
split_index =int(len(labels) * 2 / 3) 
X_train = imgs[:split_index]
y_train = labels[:split_index]
X_test = imgs[split_index:]
y_test = labels[split_index:]

X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])

print (X_train.shape)
print (X_test.shape)
# Out:
# (28000, 785)
# (14000, 785)

# %%
X_train_feats = (X_train - np.mean(X_train)) / np.std(X_train) # choose and extract features
X_test_feats = (X_test - np.mean(X_test)) / np.std(X_test) # choose and extract features

# %%
# Start training. 
# You should update your code in DSVC/classifiers/logistic_regression.py .
# Then run this cell.

classifier = LogisticRegression()
classifier.one_vs_all(
    X_train_feats, 
    y_train,
    learning_rate = 1e-2,
    num_iters = 500,
    batch_size = 64,

)
# Out:
# iteration 0 / 10: loss 0.695643
# iteration 100 / 10: loss 0.067016
# iteration 200 / 10: loss 0.041833
# iteration 300 / 10: loss 0.022968
# iteration 400 / 10: loss 0.114376
# 0-----------------------
# iteration 0 / 10: loss 6.270291
# iteration 100 / 10: loss 0.145323
# iteration 200 / 10: loss 0.083065
# iteration 300 / 10: loss 0.061988
# iteration 400 / 10: loss 0.032650
# 1-----------------------
# iteration 0 / 10: loss 5.700024
# iteration 100 / 10: loss 0.009649
# iteration 200 / 10: loss 0.003320
# iteration 300 / 10: loss 0.004020
# iteration 400 / 10: loss 0.001037
# 2-----------------------
# iteration 0 / 10: loss 0.001663
# iteration 100 / 10: loss 0.001931
# iteration 200 / 10: loss 0.001306
# iteration 300 / 10: loss 0.001001
# iteration 400 / 10: loss 0.000558
# 3-----------------------
# iteration 0 / 10: loss 0.001173
# iteration 100 / 10: loss 0.001231
# iteration 200 / 10: loss 0.000549
# iteration 300 / 10: loss 0.000394
# iteration 400 / 10: loss 0.000601
# 4-----------------------
# iteration 0 / 10: loss 0.000999
# iteration 100 / 10: loss 0.000214
# iteration 200 / 10: loss 0.000519
# iteration 300 / 10: loss 0.000434
# iteration 400 / 10: loss 0.000298
# 5-----------------------
# iteration 0 / 10: loss 0.000454
# iteration 100 / 10: loss 0.000421
# iteration 200 / 10: loss 0.000309
# iteration 300 / 10: loss 0.000372
# iteration 400 / 10: loss 0.000315
# 6-----------------------
# iteration 0 / 10: loss 0.000262
# iteration 100 / 10: loss 0.001643
# iteration 200 / 10: loss 0.000292
# iteration 300 / 10: loss 0.000160
# iteration 400 / 10: loss 0.000164
# 7-----------------------
# iteration 0 / 10: loss 0.000295
# iteration 100 / 10: loss 0.000116
# iteration 200 / 10: loss 0.000200
# iteration 300 / 10: loss 0.000129
# iteration 400 / 10: loss 0.000140
# 8-----------------------
# iteration 0 / 10: loss 0.000238
# iteration 100 / 10: loss 0.000268
# iteration 200 / 10: loss 0.000223
# iteration 300 / 10: loss 0.000307
# iteration 400 / 10: loss 0.000424
# 9-----------------------

# %%
# you may change your code in function `predict`
y_test_pred = classifier.one_vs_all_predict(X_test_feats)
print("The accruacy socre is ", np.mean(y_test == y_test_pred))
# Out:
# The accruacy socre is  0.9872142857142857
