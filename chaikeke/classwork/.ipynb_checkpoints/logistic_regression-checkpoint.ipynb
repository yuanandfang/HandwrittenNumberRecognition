# %% [markdown]
# # Logistic Regression exercise

# %%
import random #随机生成
import numpy as np #高级的数值编程工具，存储和处理大型数据
import matplotlib.pyplot as plt #绘图
import pandas as pd #数据导入及整理

# %matplotlib inline
plt.rcParams['figure.figsize'] = (15., 12.) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# pylot使用rc配置文件来自定义图形的各种默认属性，称之为rc配置或rc参数。通过rc参数可以修改默认的属性，包括窗体大小、每英寸的点数、线条宽度、颜色、样式、坐标轴、坐标和网络属性、文本、字体等。

# %%
# Read the data for you
data = pd.read_csv('./DSVC/datasets/MNIST.csv',header=0).values # change the path by yourself
imgs = data[0::,1::]
labels = data[::,0]

# %%
print(data.shape)
print(imgs.shape)
# Out:
# (42000, 785)
# (42000, 784)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = range(10)
num_classes = len(classes)#类别数目
samples_per_class = 7#每个类别的采样个数
for y, cls in enumerate(classes):#对列表的元素位置和元素进行循环，y表示元阿苏位置（0，num_class）,cls元素本身等
    idxs = np.flatnonzero(labels == y)#找出标签中y类的位置
    idxs = np.random.choice(idxs, samples_per_class, replace=False)#从中选择我们需要的7个样本
    for i, idx in enumerate(idxs):#对所选样本的位置和样本所对应的图片在训练集中的位置进行循环
        plt_idx = i * num_classes + y + 1#在子图中所占位置的计算
        plt.subplot(samples_per_class, num_classes, plt_idx)#说明要画的子图的编号
        plt.imshow(imgs[idx].reshape(28,28).astype('uint8'))#画图
        plt.axis('off')
        if i == 0:
            plt.title(cls)#写上标题，即类别名
plt.show()#显示

# %% [markdown]
# # Binary classification
# We use the Logistic Regression to classification handwritten digits wheather it's zero or not. If the handwritten digits is '0' , then the label is 0, otherwise, the label is 1.

# %%
# transform the labels to binary
for i in range(len(labels)):
    if labels[i] != 0:
        labels[i] = 1
        
# 2/3 training set
# 1/3 test set
split_index = len(labels) * 2 / 3
X_train = imgs[:int(split_index)]
y_train = labels[:int(split_index)]
X_test = imgs[int(split_index):]
y_test = labels[int(split_index):]

X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])

print(X_train.shape)
print(X_test.shape)
# Out:
# (28000, 785)
# (14000, 785)

# %% [markdown]
# 标准化

# %%
X_train_feats = X_train#(X_train - np.mean(X_train)) / np.std(X_train)#std为求其标准差
X_test_feats =X_test# (X_test - np.mean(X_test)) / np.std(X_test)

# %%
print(X_train_feats.shape)
# Out:
# (28000, 785)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = range(2)
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(labels == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(imgs[idx].reshape(28,28).astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
from DSVC.classifiers import LogisticRegression

# Start training. 
# You should open DSVC/classifiers/logistic_regression.py and implement the function.
# Then run this cell.

classifier = LogisticRegression()
loss_history = classifier.train(
    X_train_feats, 
    y_train,
    learning_rate = 1e-3,
    num_iters = 500,
    batch_size = 64,
)
# Out:
# iteration 0 / 500: loss 0.699096
# iteration 100 / 500: loss 0.228378
# iteration 200 / 500: loss 0.144205
# iteration 300 / 500: loss 0.111080
# iteration 400 / 500: loss 0.154034

# %%
plt.plot(loss_history)

# %%
y_test_pred = classifier.predict(X_test_feats)
print("The accuracy socre is ", np.mean(y_test == y_test_pred))
# Out:
# The accuracy socre is  0.9771428571428571

# %% [markdown]
# you should get the accuracy higher than 96%.
#
# ----
#
# ### F1-Measure
# Notice that, if our model always output '1', totally ignoring the input X, we can get a accuracy 90%.So, in this assignment, accuracy is not efficient enough.
#
# We will use F1-Measure to evaluate our model.
#
# You may need this:
# [F1-Measure](https://baike.baidu.com/item/f-measure/913107?fr=aladdin)

# %%
# Calculate the precision(准确率), recall(召回率) and F1
# important： We should consider label '0' as 'positive' here. 
# That means 'True positive' ==> '(y_test == 0) and (y_test_pred == 0)'

#######Your code here########
TP = 0.0#TP为true positives即预测正确的正样本
FP = 0.0#FP为false positives即预测错误的正样本
FN = 0.0#FN为false negatives即预测正确的负样本d
TN = 0.0#TN为true negatives即预测正确的负样本

#calculate TP
for it in range(785):
    if y_test_pred[it] == 0 and y_test[it] == 0:
        TP += 1.0
# print TP

#calculate FP
for it in range(785):
    if y_test_pred[it] == 0 and y_test[it] == 1:
        FP += 1.0
# print FP

#calculate FN
for it in range(785):
    if y_test_pred[it] == 1 and y_test[it] == 0:
        FN += 1.0
# print FN

#calculate TN
for it in range(785):
    if y_test_pred[it] == 1 and y_test[it] == 1:
        TN += 1.0
# print TN
    
precision = TP /(TP + FP)

recall = TP / (TP + FN)

print (precision)
print (recall)
print ('F1:', precision*recall*2/(precision+recall))
# Out:
# 1.0
# 0.8045977011494253
# F1: 0.8917197452229298

# %% [markdown]
# you should get the F1 higher than 85%.

# %% [markdown]
# # Multiclass classification
#
# Now, we use the Logistic Regression to classification handwritten digits. There are 10 class, from '0' to '9'.
#
#
# Hint: The method "one vs all" may helpful. [Here is the introduction to "one vs all"](https://msdn.microsoft.com/library/en-us/Dn905887.aspx).

# %%
# Read the data for you
data = pd.read_csv('./DSVC/datasets/MNIST.csv',header=0).values # change the path by yourself
imgs = data[0::,1::]
labels = data[::,0]
        
# 2/3 training set
# 1/3 test set
split_index = len(labels) * 2 / 3
split_index = int(split_index)
X_train = imgs[:split_index]
y_train = labels[:split_index]
X_test = imgs[split_index:]
y_test = labels[split_index:]

X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])

print (X_train.shape)
print (X_test.shape)
# Out:
# (28000, 785)
# (14000, 785)

# %%
X_train_feats = (X_train - np.mean(X_train)) / np.std(X_train)
X_test_feats = (X_test - np.mean(X_test)) / np.std(X_test)

# %%
# Start training. 
# You should update your code in DSVC/classifiers/logistic_regression.py .
# Then run this cell.

classifier = LogisticRegression()
classifier.one_vs_all(
    X_train_feats, 
    y_train,
    learning_rate = 1e-3,
    num_iters = 500,
    batch_size = 64,
)
# Out:
# it =  0
# iteration 0 / 500: loss 0.696132
# iteration 100 / 500: loss 0.200027
# iteration 200 / 500: loss 0.129584
# iteration 300 / 500: loss 0.129635
# iteration 400 / 500: loss 0.093280
# it =  1
# iteration 0 / 500: loss 0.689372
# iteration 100 / 500: loss 0.247248
# iteration 200 / 500: loss 0.117617
# iteration 300 / 500: loss 0.113139
# iteration 400 / 500: loss 0.095853
# it =  2
# iteration 0 / 500: loss 0.692493
# iteration 100 / 500: loss 0.308716
# iteration 200 / 500: loss 0.240988
# iteration 300 / 500: loss 0.198077
# iteration 400 / 500: loss 0.278517
# it =  3
# iteration 0 / 500: loss 0.691454
# iteration 100 / 500: loss 0.430117
# iteration 200 / 500: loss 0.300682
# iteration 300 / 500: loss 0.276991
# iteration 400 / 500: loss 0.309302
# it =  4
# iteration 0 / 500: loss 0.710822
# iteration 100 / 500: loss 0.332279
# iteration 200 / 500: loss 0.237032
# iteration 300 / 500: loss 0.168857
# iteration 400 / 500: loss 0.184764
# it =  5
# iteration 0 / 500: loss 0.696025
# iteration 100 / 500: loss 0.242779
# iteration 200 / 500: loss 0.215552
# iteration 300 / 500: loss 0.193270
# iteration 400 / 500: loss 0.324406
# it =  6
# iteration 0 / 500: loss 0.702968
# iteration 100 / 500: loss 0.259734
# iteration 200 / 500: loss 0.195755
# iteration 300 / 500: loss 0.152134
# iteration 400 / 500: loss 0.086377
# it =  7
# iteration 0 / 500: loss 0.696747
# iteration 100 / 500: loss 0.228083
# iteration 200 / 500: loss 0.130305
# iteration 300 / 500: loss 0.184362
# iteration 400 / 500: loss 0.160823
# it =  8
# iteration 0 / 500: loss 0.692627
# iteration 100 / 500: loss 0.353939
# iteration 200 / 500: loss 0.292409
# iteration 300 / 500: loss 0.265015
# iteration 400 / 500: loss 0.212521
# it =  9
# iteration 0 / 500: loss 0.697375
# iteration 100 / 500: loss 0.224479
# iteration 200 / 500: loss 0.289350
# iteration 300 / 500: loss 0.273920
# iteration 400 / 500: loss 0.330004

# %%
# you may change your code in function `predict`
y_test_pred = classifier.predict(X_test_feats)
print("The accruacy socre is ", np.mean(y_test == y_test_pred))
# Out:
# The accruacy socre is  0.10078571428571428

# %%
y_test_pred = classifier.one_vs_all_predict(X_test_feats)
print ("The accruacy socre is ", np.mean(y_test == y_test_pred))
# Out:
# The accruacy socre is  0.8307857142857142
